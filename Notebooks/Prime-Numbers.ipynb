# %%
# %run "C:/Users/mesteves/OneDrive - BI4ALL/Documents/MiniDatabricks/Notebooks/CommonFunctions.ipynb"
# Out:
# Function to display dataframe nicely: displayNiceDF(df, qtyRows)
# Function to display Line Chart as image: displayLineChartImg(df, xAxis, yAxis, title)
# Function to display interactive Bar Chart: displayBarChart(df, xAxis, yAxis, title)
# Function to display interactive Line Chart: displayLineChart(df, xAxis, yAxis, title)

# %%
file_path = "C:\\Users\\mesteves\\OneDrive - BI4ALL\\Documents\\MiniDatabricks\\Setup Files\\Datasets\\prime-numbers\\1m.csv"
file_path = file_path.replace('\\', '/')
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Rank  Num  Interval
# 0     1    2         2
# 1     2    3         1
# 2     3    5         2
# 3     4    7         2
# 4     5   11         4

# %%
df_2 = df.head(1000)

# %%
ax = df_2.plot(kind='line', linestyle='-', x='Num', y='Interval', rot='vertical', grid=True, figsize=(22, 10), title='Num x Interval')

#ax.set_xticks(df['Num'])
ax.set_yticks(df_2['Interval'])

ax.xaxis.set_major_formatter(FuncFormatter(format_with_commas))

plt.show()

# %%
#ax = df_2.plot(kind='line', linestyle='-', x='Rank', y='Interval', rot='vertical', figsize=(22, 10), title='Num x Interval')
ax = df_2.plot(kind='line', linestyle='-', x='Rank', y='Interval', rot='vertical', figsize=(30, 10), title='Rank x Interval')

#ax.set_xticks(df['Num'])
ax.set_yticks(df_2['Interval'])

ax.xaxis.set_major_formatter(FuncFormatter(format_with_commas))

plt.show()

# %%
df['Interval_Variance'] = df['Interval'] - df['Interval'].shift(1)

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#    Rank  Num  Interval  Interval_Variance
# 0     1    2         2                0.0
# 1     2    3         1               -1.0
# 2     3    5         2                1.0
# 3     4    7         2                0.0
# 4     5   11         4                2.0

# %%
df_subset = df.head(500)

# Convert the subset to HTML with a scrollbar
html_with_scroll = f"<div style='max-height: 400px; overflow-y: scroll;'>{df_subset.to_html()}</div>"

# Display the HTML with scrollbar
display(HTML(html_with_scroll))
# Out:
# <div style='max-height: 400px; overflow-y: scroll;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Num</th>
#       <th>Interval</th>
#       <th>Interval_Variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>5</td>
#       <td>2</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>7</td>
#       <td>2</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>11</td>
#       <td>4</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>13</td>
#       <td>2</td>
# ...

# %%
ax = df_subset.plot(kind='line', linestyle='-', x='Rank', y='Interval_Variance', rot='vertical', figsize=(30, 10), title='Rank x Interval_Variance')

ax.set_yticks(df_subset['Interval_Variance'])

ax.xaxis.set_major_formatter(FuncFormatter(format_with_commas))

plt.show()

# %%
#ax = df_2.plot(kind='line', linestyle='-', x='Rank', y='Interval', rot='vertical', figsize=(22, 10), title='Num x Interval')
ax = df_2.head(1000).plot(kind='line', linestyle='-', x='Rank', y='Num', rot='vertical', figsize=(30, 10), title='Rank x Num')

ax.xaxis.set_major_formatter(FuncFormatter(format_with_commas))

plt.show()

# %%
df_subset_2 = df.groupby('Interval')['Interval'].count()
df_subset_2.head(80)
# Out:
# Interval
# 1           1
# 2       86028
# 4       85832
# 6      146517
# 8       62750
#         ...
# 146         1
# 148         2
# 150         1
# 152         1
# 154         3
# Name: Interval, Length: 78, dtype: int64
